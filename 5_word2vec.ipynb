# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.895437
# Nearest to over: nina, cycladic, pumps, longwave, documentary, clinical, criollo, nordic,
# Nearest to may: meyers, ruminants, dog, survived, eileen, organisational, spectre, instructive,
# Nearest to their: answered, wpa, priming, screened, needlessly, unital, aspiration, subpixels,
# Nearest to most: rugova, stimulating, ordinarily, brokers, hemispheres, hindus, marquis, teenage,
# Nearest to years: vilna, vowed, carcinogen, tzu, katzenjammer, comore, calorie, draconis,
# Nearest to first: initiated, adults, muscovy, kindergarten, nintendo, jewry, sequel, dominance,
# Nearest to five: acts, netsplit, routinely, gaspard, mobil, hipper, liguria, rees,
# Nearest to zero: caricom, realistic, blurring, biconditional, participated, aarseth, depressant, colonels,
# Nearest to four: assailant, exclaves, luminous, filmography, scraped, wrecks, sponsorship, extortion,
# Nearest to between: stored, dad, conducted, christie, replicas, duties, gonzaga, gondor,
# Nearest to when: marchers, coexist, punctuation, migrating, settles, bigfoot, jumo, triage,
# Nearest to these: jugnauth, idm, cycles, ecole, manifest, bhfuil, vulnerability, killings,
# Nearest to is: syed, outer, haute, descends, coverage, subfamilies, desi, absorbs,
# Nearest to had: to, effort, vineyards, pan, markings, shoshone, simplistic, agung,
# Nearest to states: postgraduate, battuta, monogatari, australian, unconsciousness, emulator, valeria, kiwi,
# Nearest to after: fontsize, famer, esa, regum, janis, ask, resisting, ethiopic,
# Average loss at step 2000: 4.359380
# Average loss at step 4000: 3.870917
# Average loss at step 6000: 3.791235
# Average loss at step 8000: 3.683092
# Average loss at step 10000: 3.617437
# Nearest to over: documentary, fellow, union, peculiarities, dysprosium, encased, original, cycladic,
# Nearest to may: can, gasses, survived, prairie, woodside, organisational, televangelist, rigidity,
# Nearest to their: his, its, some, braveheart, fo, medication, kitts, the,
# Nearest to most: stimulating, hemispheres, ordinarily, hindus, enveloped, goshen, drogheda, brokers,
# Nearest to years: rightfully, nunavut, discarding, vilna, boycotted, trappings, orcinus, lilac,
# Nearest to first: initiated, adults, kampuchea, cia, jewry, kindergarten, last, seller,
# Nearest to five: three, six, eight, nine, four, seven, zero, two,
# Nearest to zero: nine, seven, six, five, three, eight, four, two,
# Nearest to four: six, eight, three, five, seven, nine, two, zero,
# Nearest to between: fresno, mcleod, smoothed, anodes, spp, mahommed, konya, acrylic,
# Nearest to when: marchers, punctuation, triage, coexist, hazlitt, eduard, migrating, excommunicating,
# Nearest to these: many, idm, primogeniture, khattab, hamar, ecole, mammuthus, manifest,
# Nearest to is: was, are, has, brook, mediaeval, dme, hospitalized, leslie,
# Nearest to had: has, have, was, cannot, orphanage, turkic, venetia, motorcycles,
# Nearest to states: cetacean, unconsciousness, postgraduate, australian, taking, emulator, prose, skinner,
# Nearest to after: before, progressives, morbidity, fontsize, voice, in, for, falcone,
# Average loss at step 12000: 3.603644
# Average loss at step 14000: 3.572424
# Average loss at step 16000: 3.410053
# Average loss at step 18000: 3.460366
# Average loss at step 20000: 3.540704
# Nearest to over: documentary, fellow, cycladic, encased, without, placements, peculiarities, original,
# Nearest to may: can, would, will, might, must, could, should, cans,
# Nearest to their: his, its, her, the, some, nitrous, these, knees,
# Nearest to most: stimulating, many, some, hindus, ordinarily, enveloped, hemispheres, ppc,
# Nearest to years: rightfully, months, boycotted, discarding, days, protects, olivia, trappings,
# Nearest to first: last, adults, jewry, sequel, kampuchea, ability, duplications, eerie,
# Nearest to five: six, three, four, eight, seven, two, zero, nine,
# Nearest to zero: five, six, seven, eight, two, four, three, nine,
# Nearest to four: six, three, five, eight, seven, nine, two, zero,
# Nearest to between: from, with, spp, smoothed, sorting, fresno, scholasticus, mcleod,
# Nearest to when: where, while, was, after, eventually, breaking, that, marchers,
# Nearest to these: many, some, all, such, idm, their, conciliator, which,
# Nearest to is: was, has, are, be, were, brook, careers, quicker,
# Nearest to had: has, have, were, was, cannot, orphanage, scar, afterwards,
# Nearest to states: cetacean, postgraduate, unconsciousness, skinner, australian, taking, meltwater, prose,
# Nearest to after: before, progressives, miniszt, ahmet, when, from, brahmagupta, falcone,
# Average loss at step 22000: 3.501016
# Average loss at step 24000: 3.489488
# Average loss at step 26000: 3.484031
# Average loss at step 28000: 3.482223
# Average loss at step 30000: 3.496406
# Nearest to over: without, cycladic, documentary, rhein, fellow, encased, peculiarities, pumps,
# Nearest to may: can, would, will, must, could, should, might, sages,
# Nearest to their: its, his, the, her, these, our, your, nitrous,
# Nearest to most: stimulating, some, many, hindus, more, ppc, hemispheres, enveloped,
# Nearest to years: months, days, sungorus, rightfully, saiyan, boycotted, leanings, usability,
# Nearest to first: last, second, same, eerie, doppelbock, jewry, adults, kampuchea,
# Nearest to five: four, seven, eight, three, six, zero, nine, two,
# Nearest to zero: five, four, eight, seven, three, six, nine, two,
# Nearest to four: five, three, eight, six, seven, two, nine, zero,
# Nearest to between: from, with, mcleod, texture, mahommed, fresno, pumping, in,
# Nearest to when: where, if, after, while, during, though, for, was,
# Nearest to these: many, some, all, their, such, they, several, effect,
# Nearest to is: was, has, are, does, became, quicker, brook, had,
# Nearest to had: has, have, was, were, afterwards, is, scar, orphanage,
# Nearest to states: unconsciousness, cetacean, countries, funded, tutu, meltwater, judges, australian,
# Nearest to after: before, when, during, progressives, ahmet, from, parkland, miniszt,
# Average loss at step 32000: 3.500075
# Average loss at step 34000: 3.491902
# Average loss at step 36000: 3.452311
# Average loss at step 38000: 3.296313
# Average loss at step 40000: 3.429476
# Nearest to over: cycladic, without, documentary, niklaus, encased, about, shit, rhein,
# Nearest to may: can, would, will, should, must, could, might, mau,
# Nearest to their: its, his, her, our, the, these, your, nitrous,
# Nearest to most: more, stimulating, semites, ppc, some, hindus, many, hemispheres,
# Nearest to years: months, days, sungorus, year, usability, times, rightfully, metres,
# Nearest to first: second, last, next, doppelbock, prays, same, monopolized, frost,
# Nearest to five: seven, six, three, four, eight, two, nine, zero,
# Nearest to zero: seven, five, eight, nine, six, three, four, horticulture,
# Nearest to four: three, six, seven, five, eight, two, nine, one,
# Nearest to between: from, with, texture, mahommed, cuyahoga, through, among, baltic,
# Nearest to when: if, while, where, after, before, during, because, though,
# Nearest to these: many, some, such, they, their, several, filesystems, different,
# Nearest to is: was, if, has, are, be, jules, as, when,
# Nearest to had: has, have, was, were, never, afterwards, berkshire, dubnium,
# Nearest to states: countries, kingdom, cetacean, words, unconsciousness, nations, colleagues, funded,
# Nearest to after: before, during, when, for, miniszt, skylark, gilliam, progressives,
# Average loss at step 42000: 3.439496
# Average loss at step 44000: 3.452061
# Average loss at step 46000: 3.451846
# Average loss at step 48000: 3.354072
# Average loss at step 50000: 3.387004
# Nearest to over: cycladic, without, documentary, encased, pumps, on, about, assyrian,
# Nearest to may: can, would, could, should, will, must, might, cannot,
# Nearest to their: its, his, her, the, our, my, nitrous, your,
# Nearest to most: more, some, many, stimulating, drama, semites, ppc, primary,
# Nearest to years: days, months, sungorus, year, hospitality, times, olivia, protects,
# Nearest to first: second, last, next, same, geologic, prays, fifth, desperate,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to between: with, from, among, plastic, through, against, in, mahommed,
# Nearest to when: while, after, if, where, before, however, during, although,
# Nearest to these: many, some, several, such, those, both, all, different,
# Nearest to is: was, are, has, does, be, while, although, nasrallah,
# Nearest to had: has, have, was, were, having, stargate, afterwards, coven,
# Nearest to states: kingdom, nations, unconsciousness, colleagues, countries, cetacean, funded, tutu,
# Nearest to after: before, when, during, while, miniszt, spacesuit, parkland, from,
# Average loss at step 52000: 3.431480
# Average loss at step 54000: 3.422219
# Average loss at step 56000: 3.440830
# Average loss at step 58000: 3.396621
# Average loss at step 60000: 3.388155
# Nearest to over: cycladic, without, about, assyrian, encased, around, documentary, bitmaps,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to their: its, his, her, the, our, my, your, some,
# Nearest to most: many, more, some, stimulating, ppc, hindus, primary, among,
# Nearest to years: days, months, times, sungorus, year, minutes, hours, hospitality,
# Nearest to first: second, last, next, same, eschewing, final, only, third,
# Nearest to five: four, six, three, seven, zero, eight, nine, two,
# Nearest to zero: five, four, six, eight, seven, three, nine, two,
# Nearest to four: five, six, three, eight, seven, nine, zero, two,
# Nearest to between: with, among, from, through, plastic, cuyahoga, konya, vedanta,
# Nearest to when: if, before, after, while, because, although, during, where,
# Nearest to these: many, some, those, several, such, both, their, all,
# Nearest to is: was, are, has, does, accesses, although, be, unsettling,
# Nearest to had: has, have, was, were, afterwards, having, never, stargate,
# Nearest to states: kingdom, nations, countries, unconsciousness, places, premiers, cameroon, bleak,
# Nearest to after: before, during, when, while, through, for, spacesuit, from,
# Average loss at step 62000: 3.240120
# Average loss at step 64000: 3.255600
# Average loss at step 66000: 3.401027
# Average loss at step 68000: 3.389063
# Average loss at step 70000: 3.359647
# Nearest to over: without, cycladic, bitmaps, about, within, reclassification, meticulous, viennese,
# Nearest to may: can, will, would, could, must, might, should, cannot,
# Nearest to their: its, his, her, the, our, your, my, nitrous,
# Nearest to most: more, many, some, less, stimulating, drama, ppc, blooming,
# Nearest to years: days, months, year, decades, minutes, hours, times, purer,
# Nearest to first: second, last, next, same, third, original, final, best,
# Nearest to five: four, six, three, zero, seven, eight, nine, two,
# Nearest to zero: five, eight, six, four, three, seven, nine, two,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Nearest to between: among, with, from, through, cuyahoga, plastic, barrett, mcleod,
# Nearest to when: if, while, before, after, because, where, though, although,
# Nearest to these: many, such, some, several, those, are, different, the,
# Nearest to is: was, has, are, be, became, does, although, bracelet,
# Nearest to had: has, have, was, were, having, refused, afterwards, dubnium,
# Nearest to states: kingdom, nations, countries, premiers, unconsciousness, sdi, chrome, cta,
# Nearest to after: before, during, when, while, though, for, through, if,
# Average loss at step 72000: 3.375387
# Average loss at step 74000: 3.350111
# Average loss at step 76000: 3.311318
# Average loss at step 78000: 3.354208
# Average loss at step 80000: 3.379968
# Nearest to over: cycladic, within, between, encompassed, meticulous, about, transubstantiation, staccato,
# Nearest to may: can, could, must, would, will, might, should, cannot,
# Nearest to their: its, his, her, our, your, my, nitrous, whose,
# Nearest to most: more, many, some, less, ppc, among, stimulating, meteorite,
# Nearest to years: days, months, decades, minutes, year, times, hours, weeks,
# Nearest to first: second, last, third, next, final, best, same, overall,
# Nearest to five: four, six, seven, eight, three, nine, two, zero,
# Nearest to zero: five, seven, six, four, eight, three, nine, two,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to between: among, with, within, over, cuyahoga, through, from, against,
# Nearest to when: before, if, after, during, while, though, although, because,
# Nearest to these: those, several, many, both, such, some, they, various,
# Nearest to is: was, has, became, are, includes, nasrallah, be, becomes,
# Nearest to had: has, have, having, was, were, dubnium, refused, never,
# Nearest to states: kingdom, nations, countries, us, sdi, premiers, agust, defects,
# Nearest to after: before, during, when, while, from, in, through, though,
# Average loss at step 82000: 3.409917
# Average loss at step 84000: 3.412044
# Average loss at step 86000: 3.386085
# Average loss at step 88000: 3.352851
# Average loss at step 90000: 3.367070
# Nearest to over: within, encompassed, off, about, through, centimetres, cycladic, without,
# Nearest to may: can, could, would, should, will, must, might, cannot,
# Nearest to their: his, its, her, our, your, my, the, whose,
# Nearest to most: more, many, some, less, among, ppc, especially, all,
# Nearest to years: days, months, decades, minutes, hours, year, weeks, times,
# Nearest to first: second, last, next, original, final, same, fifth, best,
# Nearest to five: seven, four, eight, three, six, nine, two, zero,
# Nearest to zero: five, eight, seven, six, four, three, nine, two,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to between: with, among, within, against, in, from, through, konya,
# Nearest to when: before, if, after, while, where, though, during, although,
# Nearest to these: several, many, some, those, multiple, such, both, they,
# Nearest to is: was, has, are, although, nasrallah, became, be, makes,
# Nearest to had: has, have, was, were, having, never, refused, dubnium,
# Nearest to states: kingdom, countries, nations, us, minorities, subregion, cameroon, chrome,
# Nearest to after: before, during, when, while, if, through, gave, despite,
# Average loss at step 92000: 3.395853
# Average loss at step 94000: 3.251000
# Average loss at step 96000: 3.358780
# Average loss at step 98000: 3.243186
# Average loss at step 100000: 3.351478
# Nearest to over: within, centimetres, encompassed, about, around, off, bitmaps, cycladic,
# Nearest to may: can, could, should, must, would, will, might, cannot,
# Nearest to their: its, his, her, your, our, the, my, nitrous,
# Nearest to most: more, less, some, many, especially, among, several, clips,
# Nearest to years: days, months, decades, year, hours, minutes, weeks, seconds,
# Nearest to first: second, last, next, fourth, third, final, fifth, previous,
# Nearest to five: four, seven, six, three, eight, two, zero, nine,
# Nearest to zero: five, seven, eight, four, six, three, nine, two,
# Nearest to four: seven, five, eight, six, three, two, nine, zero,
# Nearest to between: among, with, through, against, within, barrett, across, into,
# Nearest to when: if, while, before, where, after, although, though, because,
# Nearest to these: several, many, some, those, multiple, various, such, numerous,
# Nearest to is: was, has, became, becomes, are, makes, contains, nasrallah,
# Nearest to had: has, have, was, were, would, having, is, never,
# Nearest to states: kingdom, nations, countries, remixed, us, subregion, governments, groups,
# Nearest to after: before, during, when, while, without, through, gave, although,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
